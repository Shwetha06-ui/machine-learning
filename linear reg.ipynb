# %% [markdown]
# ## checkpoint 1
# create a function my_slope(a,b)which would accept two points a,b as an input such as a =($x_i$,$y)where xi,yi,xj,yj denotes the value in x,y

# %%
def my_slope(a, b):
   dy = a[1]-b[1]
   dx= a[0]-b[0]
   return dy/dx

# %%
#checkpoint create a 2D point class
class point:
    """
    """
